# %%
# !pip install pandas_ta
# !pip install TA-Lib
# !pip install ta

# %%
import os
print(os.getcwd())
print(sorted(os.listdir()))

from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/Colab Notebooks')
print(sorted(os.listdir()))
# Out:
# /content
# ['.config', 'sample_data']
# Mounted at /content/drive
# ['NEDL_Bollinger_Bands_.ipynb', 'NEDL_Efficient_Portfolio_Frontier_.ipynb', 'NEDL_Garch_Python_.ipynb', 'NEDL_Technical_trading_MACD_.ipynb', 'NEDL_Technical_trading_RSI.ipynb', 'NEDL_Technical_trading_RSI_.ipynb', 'NEWLSTM_.ipynb', '__pycache__', 'stable-diffusion.ipynb', 'test_TLT.ipynb', 'test_cl (1).ipynb', 'test_cl.ipynb', 'test_es.ipynb', 'test_gc.ipynb', 'test_ko.ipynb', 'test_meta.ipynb', 'test_ng.ipynb', 'test_rty.ipynb', 'test_rut.ipynb', 'test_spx.ipynb', 'test_t.ipynb', 'test_ta_packages.ipynb', 'tools']

# %%
# Google Colab

from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/github/quant_dev/notebooks')
print(sorted(os.listdir()))

# %%
# Google Colab

from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/github/quant_dev/notebooks')
print(sorted(os.listdir()))

# %%
from src.tools.basic import *

# %%
start_date = '2016-01-01'
end_date = dt.datetime.strftime(dt.datetime.today(), "%Y-%m-%d")
trade_d = 250

# %%
# Note
# Dow Jones Industrial Average (DJIA) → ^DJI
# S&P 500 Index → ^GSPC
# Nasdaq Composite Index → ^IXIC
# Russell 2000 Index → ^RUT

stock = '^GSPC'
data = yf.download(stock, start_date, end_date)

# %%
data = data.droplevel(1, axis=1)

# %%
import ta
import plotly.graph_objects as go

# Calculate SMA 20
data['SMA_20'] = ta.trend.sma_indicator(data['Close'], window=20)

# Plot using Plotly
fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name='Price')])

# fig.add_trace(go.Scatter(x=data.index, y=data['Close'], mode='lines', name='Close'))
fig.add_trace(go.Scatter(x=data.index, y=data['SMA_20'], mode='lines', name='SMA 20'))
fig.update_layout(title='^GSPC Candlestick Chart with SMA 20 (ta)')

# %%
import pandas_ta as ta
import plotly.graph_objects as go

# Calculate SMA 20 using pandas_ta
data['SMA_20_pandas_ta'] = ta.sma(data['Close'], length=20)

# Plot using Plotly
fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name='Price')])

# fig.add_trace(go.Scatter(x=data.index, y=data['Close'], mode='lines', name='Close'))
fig.add_trace(go.Scatter(x=data.index, y=data['SMA_20_pandas_ta'], mode='lines', name='SMA 20 (pandas_ta)'))
fig.update_layout(title='^GSPC Candlestick Chart with SMA 20 (pandas_ta)')

fig.show()

# %%
import talib as ta
import plotly.graph_objects as go

# Calculate SMA 20 using TA-Lib
data['SMA_20_talib'] = ta.SMA(data['Close'], timeperiod=20)

# Plot using Plotly
fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name='Price')])

# fig.add_trace(go.Scatter(x=data.index, y=data['Close'], mode='lines', name='Close'))
fig.add_trace(go.Scatter(x=data.index, y=data['SMA_20_talib'], mode='lines', name='SMA 20 (TA-Lib)'))
fig.update_layout(title='^GSPC Candlestick Chart with SMA 20 (TA-Lib)')

fig.show()
